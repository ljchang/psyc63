# %%
# Install twitter package
# !pip install twitter
# !pip install prettytable
# Out:
# Requirement already satisfied (use --upgrade to upgrade): twitter in /Users/jinhyuncheong/anaconda2/lib/python2.7/site-packages
# You are using pip version 8.1.1, however version 8.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied (use --upgrade to upgrade): prettytable in /Users/jinhyuncheong/anaconda2/lib/python2.7/site-packages
# You are using pip version 8.1.1, however version 8.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'g8fC4Wy2TjPS7HTJMmT6x3JEg'
CONSUMER_SECRET = 'BdPQCTxakGArbwiJQEGhYYzlRNgdOnuwnUlbFN03KvQjupwPgk'
OAUTH_TOKEN = '3155324529-EKWuSsv7kc1HWcKEYgdUJAImLvw1i7W2VAplYvn'
OAUTH_TOKEN_SECRET = 'MKRtb91t9VMHRdnctLyrayI6Fds7z2QSBqNob8CCCsL1i'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x1046130d0>

# %% [markdown]
# # Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2016-05-17T01:42:55Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23RespectLouis', u'query': u'%23RespectLouis', u'tweet_volume': 36860, u'name': u'#RespectLouis', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23LHHATL', u'query': u'%23LHHATL', u'tweet_volume': 52059, u'name': u'#LHHATL', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23MakeABandSmaller', u'query': u'%23MakeABandSmaller', u'tweet_volume': 33368, u'name': u'#MakeABandSmaller', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23DragRace', u'query': u'%23DragRace', u'tweet_volume': 14139, u'name': u'#DragRace', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Prison+Break%22', u'query': u'%22Prison+Break%22', u'tweet_volume': 79205, u'name': u'Prison Break', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23DWTS', u'query': u'%23DWTS', u'tweet_volume': 15753, u'name': u'#DWTS', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%224+MILLONES+CON+LALI%22', u'query': u'%224+MILLONES+CON+LALI%22', u'tweet_volume': None, u'name': u'4 MILLONES CON LALI', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Isabela+Freitas%22', u'query': u'%22Isabela+Freitas%22', u'tweet_volume': None, u'name': u'Isabela Freitas', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Dana+Brooke%22', u'query': u'%22Dana+Brooke%22', u'tweet_volume': None, u'name': u'Dana Brooke', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Harrison+Barnes%22', u'query': u'%22Harrison+Barnes%22', u'tweet_volume': None, u'name': u'Harrison Barnes', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Uncancel+Faking+It%22', u'query': u'%22Uncancel+Faking+It%22', u'tweet_volume': 53529, u'name': u'Uncancel Faking It', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Selamat+Hari+Buku+Nasional%22', u'query': u'%22Selamat+Hari+Buku+Nasional%22', u'tweet_volume': None, u'name': u'Selamat Hari Buku Nasional', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Bogut', u'query': u'Bogut', u'tweet_volume': None, u'name': u'Bogut', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22GRACIAS+THE+PARTY+TOUR%22', u'query': u'%22GRACIAS+THE+PARTY+TOUR%22', u'tweet_volume': 38631, u'name': u'GRACIAS THE PARTY TOUR', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%EC%95%88%EC%82%AC%EB%A9%B4', u'query': u'%EC%95%88%EC%82%AC%EB%A9%B4', u'tweet_volume': None, u'name': u'\uc548\uc0ac\uba74', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23MafiaEGeralNoSdv', u'query': u'%23MafiaEGeralNoSdv', u'tweet_volume': 15591, u'name': u'#MafiaEGeralNoSdv', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23OKCvsGSW', u'query': u'%23OKCvsGSW', u'tweet_volume': None, u'name': u'#OKCvsGSW', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23LunesIntratable', u'query': u'%23LunesIntratable', u'tweet_volume': None, u'name': u'#LunesIntratable', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23%D8%AA%D9%83%D9%88%D9%86_%D8%A7%D9%84%D8%B3%D8%B9%D8%A7%D8%AF%D9%87', u'query': u'%23%D8%AA%D9%83%D9%88%D9%86_%D8%A7%D9%84%D8%B3%D8%B9%D8%A7%D8%AF%D9%87', u'tweet_volume': 13684, u'name': u'#\u062a\u0643\u0648\u0646_\u0627\u0644\u0633\u0639\u0627\u062f\u0647', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23QueroDizerProCrush', u'query': u'%23QueroDizerProCrush', u'tweet_volume': 80563, u'name': u'#QueroDizerProCrush', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23RodaViva', u'query': u'%23RodaViva', u'tweet_volume': None, u'name': u'#RodaViva', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23BlackInkCrew', u'query': u'%23BlackInkCrew', u'tweet_volume': None, u'name': u'#BlackInkCrew', u'promoted_content': None},  ...
#
# [{u'created_at': u'2016-05-17T01:42:55Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23LHHATL', u'query': u'%23LHHATL', u'tweet_volume': 52059, u'name': u'#LHHATL', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23MakeABandSmaller', u'query': u'%23MakeABandSmaller', u'tweet_volume': 33368, u'name': u'#MakeABandSmaller', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23DragRace', u'query': u'%23DragRace', u'tweet_volume': 14139, u'name': u'#DragRace', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23DWTS', u'query': u'%23DWTS', u'tweet_volume': 15753, u'name': u'#DWTS', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23OKCvsGSW', u'query': u'%23OKCvsGSW', u'tweet_volume': None, u'name': u'#OKCvsGSW', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Dana+Brooke%22', u'query': u'%22Dana+Brooke%22', u'tweet_volume': None, u'name': u'Dana Brooke', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Harrison+Barnes%22', u'query': u'%22Harrison+Barnes%22', u'tweet_volume': None, u'name': u'Harrison Barnes', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22K+Michelle%22', u'query': u'%22K+Michelle%22', u'tweet_volume': None, u'name': u'K Michelle', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Bogut', u'query': u'Bogut', u'tweet_volume': None, u'name': u'Bogut', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Bambi', u'query': u'Bambi', u'tweet_volume': 10736, u'name': u'Bambi', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Drouin', u'query': u'Drouin', u'tweet_volume': None, u'name': u'Drouin', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Kevin+Owens%22', u'query': u'%22Kevin+Owens%22', u'tweet_volume': None, u'name': u'Kevin Owens', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Prison+Break%22', u'query': u'%22Prison+Break%22', u'tweet_volume': 79205, u'name': u'Prison Break', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Enes+Kanter%22', u'query': u'%22Enes+Kanter%22', u'tweet_volume': None, u'name': u'Enes Kanter', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Roberson', u'query': u'Roberson', u'tweet_volume': None, u'name': u'Roberson', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Fleury', u'query': u'Fleury', u'tweet_volume': None, u'name': u'Fleury', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Brad+Ausmus%22', u'query': u'%22Brad+Ausmus%22', u'tweet_volume': None, u'name': u'Brad Ausmus', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22David+Lee%22', u'query': u'%22David+Lee%22', u'tweet_volume': None, u'name': u'David Lee', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Carlito', u'query': u'Carlito', u'tweet_volume': None, u'name': u'Carlito', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Vasilevskiy', u'query': u'Vasilevskiy', u'tweet_volume': None, u'name': u'Vasilevskiy', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Flagrant+1%22', u'query': u'%22Flagrant+1%22', u'tweet_volume': None, u'name': u'Flagrant 1', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Waiters', u'query': u'Waiters', u'tweet_volume': None, u'name': u'Waiters', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Phil+Kessel%22', u'query': u'%22Phil+Kessel%22', u'tweet_volume': None, u'name': u'Phil Kessel', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23BlackInkCrew', u'query': u'%23BlackInkCrew', u'tweet_volume': None, u'name': u'#BlackInkCrew', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23BatesMotel', u'query': u'%23BatesMotel', u'tweet_volume': 12108, u'name': u'#BatesMotel', u'promoted_content': None}, {u'url': u'http://twitter.com/ ...

# %% [markdown]
# # Displaying API responses as pretty-printed JSON

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2016-05-17T01:42:55Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23RespectLouis",
#     "query": "%23RespectLouis",
#     "tweet_volume": 36860,
#     "name": "#RespectLouis",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LHHATL",
#     "query": "%23LHHATL",
#     "tweet_volume": 52059,
#     "name": "#LHHATL",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MakeABandSmaller",
#     "query": "%23MakeABandSmaller",
#     "tweet_volume": 33368,
#     "name": "#MakeABandSmaller",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DragRace",
#     "query": "%23DragRace",
#     "tweet_volume": 14139,
#     "name": "#DragRace",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Prison+Break%22",
#     "query": "%22Prison+Break%22",
#     "tweet_volume": 79205,
#     "name": "Prison Break",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DWTS",
#     "query": "%23DWTS",
#     "tweet_volume": 15753,
#     "name": "#DWTS",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%224+MILLONES+CON+LALI%22",
#     "query": "%224+MILLONES+CON+LALI%22",
#     "tweet_volume": null,
#     "name": "4 MILLONES CON LALI",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Isabela+Freitas%22",
#     "query": "%22Isabela+Freitas%22",
#     "tweet_volume": null,
#     "name": "Isabela Freitas",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Dana+Brooke%22",
#     "query": "%22Dana+Brooke%22",
#     "tweet_volume": null,
#     "name": "Dana Brooke",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Harrison+Barnes%22",
#     "query": "%22Harrison+Barnes%22",
#     "tweet_volume": null,
#     "name": "Harrison Barnes",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Uncancel+Faking+It%22",
#     "query": "%22Uncancel+Faking+It%22",
#     "tweet_volume": 53529,
#     "name": "Uncancel Faking It",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Selamat+Hari+Buku+Nasional%22",
#     "query": "%22Selamat+Hari+Buku+Nasional%22",
#     "tweet_volume": null,
#     "name": "Selamat Hari Buku Nasional",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Bogut",
#     "query": "Bogut",
#     "tweet_volume": null,
#     "name": "Bogut",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22GRACIAS+THE+PARTY+TOUR%22",
#     "query": "%22GRACIAS+THE+PARTY+TOUR%22",
#     "tweet_volume": 38631,
#     "name": "GRACIAS THE PARTY TOUR",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%EC%95%88%EC%82%AC%EB%A9%B4",
#     "query": "%EC%95%88%EC%82%AC%EB%A9%B4",
#     "tweet_volume": null,
#     "name": "\uc548\uc0ac\uba74",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MafiaEGeralNoSdv",
#     "query": "%23MafiaEGeralNoSdv",
#     "tweet_volume": 15591,
#     "name": "#MafiaEGeralNoSdv",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OKCvsGSW",
#     "query": "%23OKCvsGSW",
#     "tweet_volume": null,
#     "name": "#OKCvsGSW",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LunesIntratable",
#     "query": "%23LunesIntratable",
#     "tweet_volume": null,
#     "name": "#LunesIntratable",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%AA%D9%83%D9%88%D9%86_%D8%A7%D9%84%D8%B3%D8%B9%D8%A7%D8%AF%D9%87",
#     "query": "%23%D8%AA%D9%83%D9%88%D9%86_%D8%A7%D9%84%D8%B3%D8%B9%D8%A7%D8%AF%D9%87",
#     "tweet_volume": 13684,
#     "name": "#\u062a\u0643\u0648\u0646_\u0627\u0644\u0633\u0639\u0627\u062f\u0647",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23QueroDizerProCrush",
#     "query": "%23QueroDizerProCrush",
#     "tweet_volume": 80563,
#     "name": "#QueroDizerProCrush",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RodaViva",
#     "query": "%23RodaViva",
#     "tweet_volume": null,
#     "name": "#RodaViva",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BlackInkCrew",
#     "query": "%23BlackInkCrew",
#     "tweet_volume": null,
#     "name": "#BlackInkCrew",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MacriOffshore",
#     "query": "%23MacriOffshore",
#     "tweet_volume": 16225,
#     "name": "#MacriOffshore",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SOSVzlaEnDictadura",
#     "query": "%23SOSVzlaEnDictadura",
#     "tweet_volume": 28065,
#     "name": "#SOSVzlaEnDictadura",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%85%D9%86_%D9%85%D8%AD%D8%A7%D8%B3%D9%86_%D8%A7%D9%84%D8%AA%D9%82%D8%AF%D9%85_%D9%81%D9%8A_%D8%A7%D9%84%D8%B9%D9%85%D8%B1",
#     "query": "%23%D9%85%D9%86_%D9%85%D8%AD%D8%A7%D8%B3%D9%86_%D8%A7%D9%84%D8%AA%D9%82%D8%AF%D9%85_%D9%81%D9%8A_%D8%A7%D9%84%D8%B9%D9%85%D8%B1",
#     "tweet_volume": null,
#     "name": "#\u0645\u0646_\u0645\u062d\u0627\u0633\u0646_\u0627\u0644\u062a\u0642\u062f\u0645_\u0641\u064a_\u0627\u0644\u0639\u0645\u0631",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MyRelationshipStatus",
#     "query": "%23MyRelationshipStatus",
#     "tweet_volume": 35776,
#     "name": "#MyRelationshipStatus",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JaneTheVirgin",
#     "query": "%23JaneTheVirgin",
#     "tweet_volume": null,
#     "name": "#JaneTheVirgin",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LasAmazonas",
#     "query": "%23LasAmazonas",
#     "tweet_volume": 10864,
#     "name": "#LasAmazonas",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23VoiceSemiFinals",
#     "query": "%23VoiceSemiFinals",
#     "tweet_volume": 24624,
#     "name": "#VoiceSemiFinals",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%86%D9%81%D8%B3%D9%8A_%D8%A7%D8%AA%D8%AE%D9%84%D8%B5_%D9%85%D9%86",
#     "query": "%23%D9%86%D9%81%D8%B3%D9%8A_%D8%A7%D8%AA%D8%AE%D9%84%D8%B5_%D9%85%D9%86",
#     "tweet_volume": 19191,
#     "name": "#\u0646\u0641\u0633\u064a_\u0627\u062a\u062e\u0644\u0635_\u0645\u0646",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RAWCL",
#     "query": "%23RAWCL",
#     "tweet_volume": null,
#     "name": "#RAWCL",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SiYoFuera",
#     "query": "%23SiYoFuera",
#     "tweet_volume": null,
#     "name": "#SiYoFuera",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TemerCaraDePau",
#     "query": "%23TemerCaraDePau",
#     "tweet_volume": 17424,
#     "name": "#TemerCaraDePau",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23UnlikelyScientificDiscoveries",
#     "query": "%23UnlikelyScientificDiscoveries",
#     "tweet_volume": null,
#     "name": "#UnlikelyScientificDiscoveries",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ArgentinaNeedsPurposeTour",
#     "query": "%23ArgentinaNeedsPurposeTour",
#     "tweet_volume": 47020,
#     "name": "#ArgentinaNeedsPurposeTour",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ExtremeRules",
#     "query": "%23ExtremeRules",
#     "tweet_volume": 10918,
#     "name": "#ExtremeRules",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%231MSinTuAmor",
#     "query": "%231MSinTuAmor",
#     "tweet_volume": null,
#     "name": "#1MSinTuAmor",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SouthernCharm",
#     "query": "%23SouthernCharm",
#     "tweet_volume": null,
#     "name": "#SouthernCharm",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%81%D9%87%D8%AF_%D8%A7%D9%84%D9%85%D9%88%D9%84%D8%AF_%D8%A7%D9%87%D9%84%D8%A7%D9%88%D9%8A",
#     "query": "%23%D9%81%D9%87%D8%AF_%D8%A7%D9%84%D9%85%D9%88%D9%84%D8%AF_%D8%A7%D9%87%D9%84%D8%A7%D9%88%D9%8A",
#     "tweet_volume": 24436,
#     "name": "#\u0641\u0647\u062f_\u0627\u0644\u0645\u0648\u0644\u062f_\u0627\u0647\u0644\u0627\u0648\u064a",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JorgeRodriguezEresUnParasito",
#     "query": "%23JorgeRodriguezEresUnParasito",
#     "tweet_volume": null,
#     "name": "#JorgeRodriguezEresUnParasito",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TgrsSdvTrocoFdpPor",
#     "query": "%23TgrsSdvTrocoFdpPor",
#     "tweet_volume": 13291,
#     "name": "#TgrsSdvTrocoFdpPor",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23KNOTFESTMEXICO2016",
#     "query": "%23KNOTFESTMEXICO2016",
#     "tweet_volume": null,
#     "name": "#KNOTFESTMEXICO2016",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BodorrioMdT",
#     "query": "%23BodorrioMdT",
#     "tweet_volume": 31939,
#     "name": "#BodorrioMdT",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FrasesDeProfesor",
#     "query": "%23FrasesDeProfesor",
#     "tweet_volume": null,
#     "name": "#FrasesDeProfesor",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AB%C3%ADbliaMeEnsinou",
#     "query": "%23AB%C3%ADbliaMeEnsinou",
#     "tweet_volume": null,
#     "name": "#AB\u00edbliaMeEnsinou",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B3%D8%A7%D8%AD%D8%B1%D9%87_%D8%AA%D8%AD%D9%88%D9%84_%D9%88%D9%84%D8%AF_%D8%A7%D9%84%D9%8A_%D9%83%D8%A8%D8%A7%D8%AC%D9%8A",
#     "query": "%23%D8%B3%D8%A7%D8%AD%D8%B1%D9%87_%D8%AA%D8%AD%D9%88%D9%84_%D9%88%D9%84%D8%AF_%D8%A7%D9%84%D9%8A_%D9%83%D8%A8%D8%A7%D8%AC%D9%8A",
#     "tweet_volume": null,
#     "name": "#\u0633\u0627\u062d\u0631\u0647_\u062a\u062d\u0648\u0644_\u0648\u0644\u062f_\u0627\u0644\u064a_\u0643\u0628\u0627\u062c\u064a",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GraciasTotalesDAM22",
#     "query": "%23GraciasTotalesDAM22",
#     "tweet_volume": null,
#     "name": "#GraciasTotalesDAM22",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ILearnedTheHardWayThat",
#     "query": "%23ILearnedTheHardWayThat",
#     "tweet_volume": null,
#     "name": "#ILearnedTheHardWayThat",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PapoDeSegundaNoGNT",
#     "query": "%23PapoDeSegundaNoGNT",
#     "tweet_volume": null,
#     "name": "#PapoDeSegundaNoGNT",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%AA%D9%88%D9%8A%D8%AA%D9%87_%D8%A7%D9%84%D8%B3%D9%8A%D8%B3%D9%8A_%D9%87%D9%8A%D8%B4%D9%88%D9%81%D9%87%D8%A7",
#     "query": "%23%D8%AA%D9%88%D9%8A%D8%AA%D9%87_%D8%A7%D9%84%D8%B3%D9%8A%D8%B3%D9%8A_%D9%87%D9%8A%D8%B4%D9%88%D9%81%D9%87%D8%A7",
#     "tweet_volume": 14248,
#     "name": "#\u062a\u0648\u064a\u062a\u0647_\u0627\u0644\u0633\u064a\u0633\u064a_\u0647\u064a\u0634\u0648\u0641\u0647\u0627",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-05-17T01:49:52Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2016-05-17T01:42:55Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23LHHATL",
#     "query": "%23LHHATL",
#     "tweet_volume": 52059,
#     "name": "#LHHATL",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MakeABandSmaller",
#     "query": "%23MakeABandSmaller",
#     "tweet_volume": 33368,
#     "name": "#MakeABandSmaller",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DragRace",
#     "query": "%23DragRace",
#     "tweet_volume": 14139,
#     "name": "#DragRace",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DWTS",
#     "query": "%23DWTS",
#     "tweet_volume": 15753,
#     "name": "#DWTS",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OKCvsGSW",
#     "query": "%23OKCvsGSW",
#     "tweet_volume": null,
#     "name": "#OKCvsGSW",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Dana+Brooke%22",
#     "query": "%22Dana+Brooke%22",
#     "tweet_volume": null,
#     "name": "Dana Brooke",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Harrison+Barnes%22",
#     "query": "%22Harrison+Barnes%22",
#     "tweet_volume": null,
#     "name": "Harrison Barnes",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22K+Michelle%22",
#     "query": "%22K+Michelle%22",
#     "tweet_volume": null,
#     "name": "K Michelle",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Bogut",
#     "query": "Bogut",
#     "tweet_volume": null,
#     "name": "Bogut",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Bambi",
#     "query": "Bambi",
#     "tweet_volume": 10736,
#     "name": "Bambi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Drouin",
#     "query": "Drouin",
#     "tweet_volume": null,
#     "name": "Drouin",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Kevin+Owens%22",
#     "query": "%22Kevin+Owens%22",
#     "tweet_volume": null,
#     "name": "Kevin Owens",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Prison+Break%22",
#     "query": "%22Prison+Break%22",
#     "tweet_volume": 79205,
#     "name": "Prison Break",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Enes+Kanter%22",
#     "query": "%22Enes+Kanter%22",
#     "tweet_volume": null,
#     "name": "Enes Kanter",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Roberson",
#     "query": "Roberson",
#     "tweet_volume": null,
#     "name": "Roberson",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Fleury",
#     "query": "Fleury",
#     "tweet_volume": null,
#     "name": "Fleury",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Brad+Ausmus%22",
#     "query": "%22Brad+Ausmus%22",
#     "tweet_volume": null,
#     "name": "Brad Ausmus",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22David+Lee%22",
#     "query": "%22David+Lee%22",
#     "tweet_volume": null,
#     "name": "David Lee",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Carlito",
#     "query": "Carlito",
#     "tweet_volume": null,
#     "name": "Carlito",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Vasilevskiy",
#     "query": "Vasilevskiy",
#     "tweet_volume": null,
#     "name": "Vasilevskiy",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Flagrant+1%22",
#     "query": "%22Flagrant+1%22",
#     "tweet_volume": null,
#     "name": "Flagrant 1",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Waiters",
#     "query": "Waiters",
#     "tweet_volume": null,
#     "name": "Waiters",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Phil+Kessel%22",
#     "query": "%22Phil+Kessel%22",
#     "tweet_volume": null,
#     "name": "Phil Kessel",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BlackInkCrew",
#     "query": "%23BlackInkCrew",
#     "tweet_volume": null,
#     "name": "#BlackInkCrew",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BatesMotel",
#     "query": "%23BatesMotel",
#     "tweet_volume": 12108,
#     "name": "#BatesMotel",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Gotham",
#     "query": "%23Gotham",
#     "tweet_volume": 18188,
#     "name": "#Gotham",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JaneTheVirgin",
#     "query": "%23JaneTheVirgin",
#     "tweet_volume": null,
#     "name": "#JaneTheVirgin",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23VoiceSemiFinals",
#     "query": "%23VoiceSemiFinals",
#     "tweet_volume": 24624,
#     "name": "#VoiceSemiFinals",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SouthernCharm",
#     "query": "%23SouthernCharm",
#     "tweet_volume": null,
#     "name": "#SouthernCharm",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23UnlikelyScientificDiscoveries",
#     "query": "%23UnlikelyScientificDiscoveries",
#     "tweet_volume": null,
#     "name": "#UnlikelyScientificDiscoveries",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RespectLouis",
#     "query": "%23RespectLouis",
#     "tweet_volume": 36860,
#     "name": "#RespectLouis",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MyRelationshipStatus",
#     "query": "%23MyRelationshipStatus",
#     "tweet_volume": 35776,
#     "name": "#MyRelationshipStatus",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ILearnedTheHardWayThat",
#     "query": "%23ILearnedTheHardWayThat",
#     "tweet_volume": null,
#     "name": "#ILearnedTheHardWayThat",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23commandtheunsullied",
#     "query": "%23commandtheunsullied",
#     "tweet_volume": 126343,
#     "name": "#commandtheunsullied",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Webbys",
#     "query": "%23Webbys",
#     "tweet_volume": null,
#     "name": "#Webbys",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MikeandMolly",
#     "query": "%23MikeandMolly",
#     "tweet_volume": null,
#     "name": "#MikeandMolly",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23inners",
#     "query": "%23inners",
#     "tweet_volume": null,
#     "name": "#inners",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TMOMZS60",
#     "query": "%23TMOMZS60",
#     "tweet_volume": null,
#     "name": "#TMOMZS60",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WWERaw",
#     "query": "%23WWERaw",
#     "tweet_volume": null,
#     "name": "#WWERaw",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PENgala",
#     "query": "%23PENgala",
#     "tweet_volume": null,
#     "name": "#PENgala",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HoudiniAndDoyle",
#     "query": "%23HoudiniAndDoyle",
#     "tweet_volume": null,
#     "name": "#HoudiniAndDoyle",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23KellyFile",
#     "query": "%23KellyFile",
#     "tweet_volume": null,
#     "name": "#KellyFile",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-05-17T01:49:52Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %% [markdown]
# # Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'#MyRelationshipStatus', u'#UnlikelyScientificDiscoveries', u'Prison Break', u'#LHHATL', u'#BlackInkCrew', u'#VoiceSemiFinals', u'#SouthernCharm', u'#MakeABandSmaller', u'Bogut', u'Dana Brooke', u'#RespectLouis', u'#ILearnedTheHardWayThat', u'Harrison Barnes', u'#DragRace', u'#DWTS', u'#OKCvsGSW', u'#JaneTheVirgin'])

# %% [markdown]
# # Example 5. Collecting search results

# %%
# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#MentionSomeoneImportantForYou' 
q = 'trump'

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print json.dumps(statuses[0], indent=1)
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 300
# Length of statuses 400
# Length of statuses 500
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "@SarahPlishka @_michelletbh honestly you are the type to go for Hilary aren't you . go for trump best decision I can say that you make",
#  "is_quote_status": false,
#  "in_reply_to_status_id": 732388399521406977,
#  "id": 732388637782859776,
#  "favorite_count": 0,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 900791226,
#     "indices": [
#      0,
#      13
#     ],
#     "id_str": "900791226",
#     "screen_name": "SarahPlishka",
#     "name": "\u2741"
#    },
#    {
#     "id": 729028452,
#     "indices": [
#      14,
#      27
#     ],
#     "id_str": "729028452",
#     "screen_name": "_michelletbh",
#     "name": "Michelle"
#    }
#   ],
#   "hashtags": [],
#   "urls": []
#  },
#  "retweeted": false,
#  "coordinates": null,
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_screen_name": "SarahPlishka",
#  "in_reply_to_user_id": 900791226,
#  "retweet_count": 0,
#  "id_str": "732388637782859776",
#  "favorited": false,
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 2736570622,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/695027275482415104/zrQoo-YR_normal.jpg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 246,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "2736570622",
#   "profile_background_color": "C0DEED",
#   "listed_count": 1,
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 3059,
#   "description": "clifton puck #3",
#   "friends_count": 237,
#   "location": "",
#   "profile_link_color": "0084B4",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/695027275482415104/zrQoo-YR_normal.jpg",
#   "following": false,
#   "geo_enabled": true,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2736570622/1454542384",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "shawn0398",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 3144,
#   "name": "shawn_meneghin",
#   "notifications": false,
#   "url": null,
#   "created_at": "Thu Aug 07 20:54:29 +0000 2014",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": true,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": "900791226",
#  "lang": "en",
#  "created_at": "Tue May 17 01:53:53 +0000 2016",
#  "in_reply_to_status_id_str": "732388399521406977",
#  "place": null,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }

# %% [markdown]
# # Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print json.dumps(status_texts[0:10], indent=1)
print json.dumps(screen_names[0:10], indent=1) 
print json.dumps(hashtags[0:10], indent=1)
print json.dumps(words[0:10], indent=1)
# Out:
# [
#  "@SarahPlishka @_michelletbh honestly you are the type to go for Hilary aren't you . go for trump best decision I can say that you make",
#  "RT @MrEmilyHeller: Why do I get the feeling Trump is gonna Mrs. Doubtfire himself to be his own running mate",
#  "Trump Releases His Plan for 2nd Amendment... Leaves Millions Furious https://t.co/2CRSEPwCAg",
#  "Teanna trump addressed everyone saying she's retarded on Snapchat by saying she isn't...then went about being retarded.",
#  "RT @trump_world: \"#Trump was extraordinarily professional. He was very tough, but he was fair.\" @SenadaAdzem #KellyFile https://t.co/YgaQ69\u2026",
#  "RT @geoffgarin: Of course Hill GOPers share Trump's goal of slashing taxes for the rich, overturning Roe, and deporting immigrants  https:/\u2026",
#  "RT @BillGoltz: I quit watching #KellyFile  Not because of the Trump thing. She seems to be leaning lib. #oreillyfactor",
#  "RT @MrEmilyHeller: Why do I get the feeling Trump is gonna Mrs. Doubtfire himself to be his own running mate",
#  "RT @Louistrc: @realDonaldTrump When will #MSM realize #Trump Supporters only dig in more when they do #STUPID Attacks on him!Shows how #STU\u2026",
#  "RT @UniteWomenDE: Bette Midler Destroys Trump With This Brilliant Quote From \u201cCatch-22\u201d - https://t.co/pGsRBl5uUd https://t.co/b8Ot1tgig4"
# ]
# [
#  "SarahPlishka",
#  "_michelletbh",
#  "MrEmilyHeller",
#  "trump_world",
#  "SenadaAdzem",
#  "geoffgarin",
#  "BillGoltz",
#  "MrEmilyHeller",
#  "Louistrc",
#  "realDonaldTrump"
# ]
# [
#  "Trump",
#  "KellyFile",
#  "KellyFile",
#  "oreillyfactor",
#  "MSM",
#  "Trump",
#  "STUPID",
#  "STUPID",
#  "MSM",
#  "Trump"
# ]
# [
#  "@SarahPlishka",
#  "@_michelletbh",
#  "honestly",
#  "you",
#  "are",
#  "the",
#  "type",
#  "to",
#  "go",
#  "for"
# ]

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common()[:10] # top 10
    print
# Out:
# [(u'RT', 392), (u'Trump', 348), (u'the', 182), (u'to', 177), (u'a', 140), (u'is', 136), (u'Donald', 120), (u'of', 104), (u'for', 86), (u'and', 74)]
#
# [(u'realDonaldTrump', 59), (u'megynkelly', 16), (u'nytimes', 16), (u'NateSilver538', 14), (u'FoxNews', 14), (u'MrEmilyHeller', 12), (u'YouTube', 11), (u'prioritiesUSA', 10), (u'BetteMidler', 7), (u'CNN', 7)]
#
# [(u'Trump', 32), (u'Trump2016', 30), (u'MAGA', 15), (u'NeverTrump', 10), (u'TrumpTrain', 10), (u'tcot', 7), (u'KellyFile', 5), (u'MakeAmericaGreatAgain', 4), (u'ccot', 4), (u'Oregon', 4)]

# %% [markdown]
# # Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt
# Out:
# +--------+-------+
# | Word   | Count |
# +--------+-------+
# | RT     |   392 |
# | Trump  |   348 |
# | the    |   182 |
# | to     |   177 |
# | a      |   140 |
# | is     |   136 |
# | Donald |   120 |
# | of     |   104 |
# | for    |    86 |
# | and    |    74 |
# +--------+-------+
# +-----------------+-------+
# | Screen Name     | Count |
# +-----------------+-------+
# | realDonaldTrump |    59 |
# | megynkelly      |    16 |
# | nytimes         |    16 |
# | NateSilver538   |    14 |
# | FoxNews         |    14 |
# | MrEmilyHeller   |    12 |
# | YouTube         |    11 |
# | prioritiesUSA   |    10 |
# | BetteMidler     |     7 |
# | CNN             |     7 |
# +-----------------+-------+
# +-----------------------+-------+
# | Hashtag               | Count |
# +-----------------------+-------+
# | Trump                 |    32 |
# | Trump2016             |    30 |
# | MAGA                  |    15 |
# | NeverTrump            |    10 |
# | TrumpTrain            |    10 |
# | tcot                  |     7 |
# | KellyFile             |     5 |
# | MakeAmericaGreatAgain |     4 |
# | ccot                  |     4 |
# | Oregon                |     4 |
# +-----------------------+-------+

# %% [markdown]
# Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print lexical_diversity(words)
print lexical_diversity(screen_names)
print lexical_diversity(hashtags)
print average_words(status_texts)
# Out:
# 0.384272997033
# 0.540078843627
# 0.489583333333
# 16.85

# %% [markdown]
# Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if status.has_key('retweeted_status')
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print pt
# Out:
# +--------+-------------+----------------------------------------------------+
# | Count  | Screen Name | Text                                               |
# +--------+-------------+----------------------------------------------------+
# | 128482 | ClassicPict | RT @ClassicPict: Donald Trump v Adolf Hitler       |
# |        |             | https://t.co/TJBmi50MhX                            |
# | 128482 | ClassicPict | RT @ClassicPict: Donald Trump v Adolf Hitler       |
# |        |             | https://t.co/TJBmi50MhX                            |
# | 33692  | BetteMidler | RT @BetteMidler: Twitter deactivated Azealia       |
# |        |             | Banks’ account for homophobia &amp; racism?        |
# |        |             | So why is Donald Trump still here?                 |
# | 33692  | BetteMidler | RT @BetteMidler: Twitter deactivated Azealia       |
# |        |             | Banks’ account for homophobia &amp; racism?        |
# |        |             | So why is Donald Trump still here?                 |
# | 33692  | BetteMidler | RT @BetteMidler: Twitter deactivated Azealia       |
# |        |             | Banks’ account for homophobia &amp; racism?        |
# |        |             | So why is Donald Trump still here?                 |
# +--------+-------------+----------------------------------------------------+

# %% [markdown]
# Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print [r['user']['screen_name'] for r in _retweets]
# Out:
# [u'jyeee', u'Ceejaynatics', u'ikaayyy_', u'RafaellaaaMae', u'LoveKyana18', u'iiaamcamillee', u'kidamgos', u'shangxshang', u'asdfghjbl', u'Papagars__', u'josellexseraspi']

# %% [markdown]
# Example 12. Plotting frequencies of words

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
plt.show()

# %% [markdown]
# Example 13. Generating histograms of words, screen names, and hashtags¶

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print counts
# Out:
# [154, 6, 28, 4, 154, 1, 31, 28, 210, 566, 3, 1, 2, 8, 3, 80, 16, 5, 70, 33692, 8, 52, 32, 15, 504, 8, 7, 169, 18, 7, 4, 15, 9, 5289, 504, 4, 19, 3, 5, 8, 10131, 84, 72, 24, 18, 9934, 1, 370, 5, 6, 6, 154, 133, 9, 6, 1, 84, 2, 77, 352, 138, 11, 19, 154, 41, 2, 14, 2, 128482, 8, 7, 165, 89, 15301, 355, 5, 6, 382, 2402, 17, 9, 33690, 8, 504, 1111, 42, 18, 5, 194, 23, 71, 1111, 7, 685, 63, 24, 2, 8, 6, 6, 13, 160, 6, 50, 15, 378, 6, 1288, 196, 2552, 2086, 223, 6, 1, 10, 9, 1111, 685, 27, 118, 104, 6, 317, 1, 43, 184, 58, 1, 15, 3, 378, 1, 39, 83, 685, 24, 3, 2, 21, 1, 28, 3, 1, 36, 214, 8, 15, 3, 8, 1, 29, 19, 154, 6, 4, 505, 70, 44, 28, 169, 192, 11, 2, 2402, 154, 21, 404, 2, 65, 264, 255, 12, 1, 10, 216, 31, 105, 314, 675, 129, 2, 3683, 51, 26, 122, 159, 3, 4, 264, 21, 505, 33688, 179, 154, 2, 3, 2, 6, 1176, 9, 2, 154, 2, 16258, 1, 6, 5, 686, 2, 464, 33688, 4, 1, 1, 15, 338, 6, 7, 3, 15, 5, 27, 17, 39, 18, 51, 2, 81, 7, 2, 13, 30, 849, 33, 2, 2, 5, 154, 566, 2552, 92, 505, 9, 1, 14, 50, 24, 9, 33692, 40, 1191, 2402, 1, 154, 2, 11, 16258, 154, 4583, 2552, 160, 16258, 1, 33, 15, 4, 7, 686, 1572, 129, 8, 5, 154, 1, 213, 3, 4602, 2402, 118, 23, 4, 169, 129, 3, 144, 298, 65, 13, 185, 2402, 1111, 70, 13, 110, 16, 374, 1, 28, 94, 16, 1, 54, 34, 505, 1, 3, 1, 1, 849, 122, 37, 6, 9, 291, 1176, 106, 4132, 3, 459, 10, 81, 18, 15, 3683, 12, 4, 7, 25, 81, 234, 6, 38, 355, 44, 15, 225, 9, 19, 11, 10, 3, 27, 66, 150, 51, 178, 35, 29, 9, 57, 69, 511, 12, 8, 8, 686, 72, 1, 382, 4, 19, 55, 59, 128482, 1, 3, 55, 41, 59, 12, 6, 1, 143, 27, 82, 129, 49, 566, 3, 33692, 33692, 3, 11]
