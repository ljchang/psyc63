# %%
# %matplotlib inline
import pandas as pd
import os
import matplotlib.pylab as plt

base_dir = '/Users/lukechang/Dropbox/Dartmouth/Teaching/Psych63_SocialPsychMethods/Labs/'

# %% [markdown]
# ### Download dataset
# Here we will download a dataset publically available from the open science foundation (OSF)
# https://osf.io/47tnc/.  We will load the data file as a comma delimited data file using pandas, a python module that makes it easy to interact with data.
#
# To see a list of the columns of the data frame type 'print data.columns'
#
# to see what the dataframe looks like type 'data'

# %%
data = pd.read_csv(os.path.join('..','Data','CrowdstormingDataJuly1st.csv'))

print data.columns

data
# Out:
# Index([u'playerShort', u'player', u'club', u'leagueCountry', u'birthday',
#        u'height', u'weight', u'position', u'games', u'victories', u'ties',
#        u'defeats', u'goals', u'yellowCards', u'yellowReds', u'redCards',
#        u'photoID', u'rater1', u'rater2', u'refNum', u'refCountry', u'Alpha_3',
#        u'meanIAT', u'nIAT', u'seIAT', u'meanExp', u'nExp', u'seExp'],
#       dtype='object')
#                   playerShort                 player                  club  \
# 0               lucas-wilchez          Lucas Wilchez         Real Zaragoza
# 1                  john-utaka             John Utaka       Montpellier HSC
# 2                 abdon-prats            Abdón Prats          RCD Mallorca
# 3                  pablo-mari             Pablo Marí          RCD Mallorca
# 4                  ruben-pena             Rubén Peña       Real Valladolid
# 5                aaron-hughes           Aaron Hughes             Fulham FC
# ...

# %% [markdown]
# How many different players are in the dataframe?

# %%
n = len(data['player'].unique())
print 'There are %d players' % n
# Out:
# There are 2034 players

# %% [markdown]
# What is the average height?  and how might we view the distribution?

# %%
print 'The mean height across %d players is %d centimeters' % (n, data['height'].mean())
data['height'].plot(kind='hist')
# Out:
# The mean height across 2034 players is 181 centimeters

# %% [markdown]
# Which position scores the most goals?

# %%
print data.columns
data['goals'].groupby(data['position']).mean().plot(kind='bar')
plt.ylabel('Mean number of goals')
# Out:
# Index([u'playerShort', u'player', u'club', u'leagueCountry', u'birthday',
#        u'height', u'weight', u'position', u'games', u'victories', u'ties',
#        u'defeats', u'goals', u'yellowCards', u'yellowReds', u'redCards',
#        u'photoID', u'rater1', u'rater2', u'refNum', u'refCountry', u'Alpha_3',
#        u'meanIAT', u'nIAT', u'seIAT', u'meanExp', u'nExp', u'seExp'],
#       dtype='object')

# %% [markdown]
# What are the top 10 teams that receive the most number of yellow cards?

# %%
data['yellowCards'].groupby(data['club']).mean().sort_values(ascending=False)[0:10]
# Out:
# club
# Villarreal CF         0.750000
# Getafe CF             0.719178
# CA Osasuna            0.710092
# Atlético Madrid       0.578469
# Espanyol Barcelona    0.573649
# Rayo Vallecano        0.559804
# Athletic Bilbao       0.557008
# Levante UD            0.548287
# Valencia CF           0.548125
# Real Betis            0.532918
# Name: yellowCards, dtype: float64

# %%
data.ix[0:10,:]
# Out:
#            playerShort              player               club leagueCountry  \
# 0        lucas-wilchez       Lucas Wilchez      Real Zaragoza         Spain
# 1           john-utaka          John Utaka    Montpellier HSC        France
# 2          abdon-prats         Abdón Prats       RCD Mallorca         Spain
# 3           pablo-mari          Pablo Marí       RCD Mallorca         Spain
# 4           ruben-pena          Rubén Peña    Real Valladolid         Spain
# 5         aaron-hughes        Aaron Hughes          Fulham FC       England
# 6   aleksandar-kolarov  Aleksandar Kolarov    Manchester City       England
# 7     alexander-tettey    Alexander Tettey       Norwich City       England
# 8    anders-lindegaard   Anders Lindegaard  Manchester United       England
# 9         andreas-beck        Andreas Beck    1899 Hoffenheim       Germany
# 10    antonio-rukavina    Antonio Rukavina    Real Valladolid         Spain
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

# %%
n_neighbors = 1
data = pd.read_csv(os.path.join('..','Data','CrowdstormingDataJuly1st.csv'))
data = data.dropna()
X =  data[['height','weight','goals','yellowCards','yellowReds','redCards']].values
y = data[['position']].values

# %%
posd = pd.Series(data.position,dtype="category")
posd.unique()
y = posd.cat.rename_categories(range(0,12))
y = y.to_frame()
y = y.values

# %%
indices = np.random.permutation(data.shape[0])
training_idx, test_idx = indices[:int(round(.8*len(indices)))],indices[int(round(.8*len(indices))):]
training_X = X[training_idx,:]
training_y = y[training_idx].reshape(len(training_idx),)
test_X = X[test_idx,:]
test_y = y[test_idx].reshape(len(test_idx),)

# %%
weights = 'uniform'
weights = 'distance'
clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
clf.fit(training_X, training_y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='distance')

# %%
predicted = clf.predict(test_X)
np.mean(predicted == test_y)
# Out:
# 0.4894980728422329

# %%
X =  data[['height','weight']].values
y = data[['position']].values
posd = pd.Series(data.position,dtype="category")
posd.unique()
y = posd.cat.rename_categories(range(0,12))
y = y.to_frame()
y = y.values
indices = np.random.permutation(data.shape[0])
training_idx, test_idx = indices[:int(round(.8*len(indices)))],indices[int(round(.8*len(indices))):]
training_X = X[training_idx,:]
training_y = y[training_idx].reshape(len(training_idx),)
test_X = X[test_idx,:]
test_y = y[test_idx].reshape(len(test_idx),)
weights = 'uniform'
weights = 'distance'
clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
clf.fit(training_X, training_y)

# Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, m_max]x[y_min, y_max].
X = test_X[:,0:2]
y = test_y
h = .02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# %%
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
    # Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF','#FFAAAA', 
                             '#ff0000', '#ff8000','#ffff00', '#40ff00', 
                             '#00ffff','#bf00ff', '#ff0080', '#ff0000'])
cmap_bold = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF','#FFAAAA', 
                             '#ff0000', '#ff8000','#ffff00', '#40ff00', 
                             '#00ffff','#bf00ff', '#ff0080', '#ff0000'])

# Put the result into a color plot
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("12-Class classification (k = %i, weights = '%s')"
          % (n_neighbors, weights))

plt.show()

# %%
# Out:
#                   playerShort                 player                  club  \
# 0               lucas-wilchez          Lucas Wilchez         Real Zaragoza
# 1                  john-utaka             John Utaka       Montpellier HSC
# 5                aaron-hughes           Aaron Hughes             Fulham FC
# 6          aleksandar-kolarov     Aleksandar Kolarov       Manchester City
# 7            alexander-tettey       Alexander Tettey          Norwich City
# 8           anders-lindegaard      Anders Lindegaard     Manchester United
# 9                andreas-beck           Andreas Beck       1899 Hoffenheim
# 10           antonio-rukavina       Antonio Rukavina       Real Valladolid
# 11             ashkan-dejagah         Ashkan Dejagah             Fulham FC
# 12          benedikt-hoewedes       Benedikt Höwedes         FC Schalke 04
# 13                chris-baird            Chris Baird             Fulham FC
# ...
